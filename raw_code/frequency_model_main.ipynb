# %%
import pandas as pd

data_path = "../hackathon_caa25/data/"

# loading x_train
data = pd.read_csv(data_path+'train_input_Z61KlZo.csv')
data.set_index('ID', inplace=True)
print("x_train", data.shape)

# loading target
target = pd.read_csv(data_path+'train_output_DzPxaPY.csv')
target.set_index('ID', inplace=True)
print("y_train", target.shape)

# joining x_train and y_train
data = data.join(target.drop("ANNEE_ASSURANCE", axis=1))
print("data", data.shape)
# Out:
# /var/folders/qf/pxq_c1s53jn0j_nkpfcjpxfm0000gn/T/ipykernel_76480/940231529.py:6: DtypeWarning: Columns (16,17,29,30,31,126,128,129,132,133,135,138,371) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path+'train_input_Z61KlZo.csv')
# x_train (383610, 373)
# y_train (383610, 4)
# data (383610, 376)

# %%
import sys
sys.path.append("../")

from hackathon_caa25.main import train_frequency_model

train_frequency_model(data)
# Out:
# 2025-09-21 23:01:37,521 - hackathon_caa25 - INFO - Starting training of frequency model.
# 2025-09-21 23:01:37,523 - hackathon_caa25 - INFO - Target column 'TARGET' created
# 2025-09-21 23:01:37,524 - hackathon_caa25 - INFO - Target distribution:
# TARGET
# 0    381060
# 1      2462
# 2        84
# 3         2
# 5         1
# 4         1
# Name: count, dtype: int64
# 2025-09-21 23:01:37,525 - hackathon_caa25 - INFO - Performing stratified sampling.
# 2025-09-21 23:01:37,525 - hackathon_caa25 - INFO - Starting dataset split.
# 2025-09-21 23:01:37,556 - hackathon_caa25 - INFO - Class weights: {0: 0.33556395318322574, 1: 51.9374492282697, 2: 1453.0681818181818}
# 2025-09-21 23:01:37,556 - hackathon_caa25 - INFO - Assigning sample weights.
# WARNING: IPython.display is available, but other dependencies are missing. Please install them using pip install AutoCarver[jupyter].
# WARNING: IPython.display is available, but other dependencies are missing. Please install them using pip install AutoCarver[jupyter].
# 2025-09-21 23:01:37,585 - hackathon_caa25 - INFO - Performing train-test split.
# 2025-09-21 23:01:38,259 - hackathon_caa25 - INFO - y_train mean: 0.006889
# 2025-09-21 23:01:38,260 - hackathon_caa25 - INFO - y_dev mean: 0.006921
# 2025-09-21 23:01:38,260 - hackathon_caa25 - INFO - x_train shape: (306888, 377)
# 2025-09-21 23:01:38,261 - hackathon_caa25 - INFO - x_dev shape: (76722, 377)
# 2025-09-21 23:01:38,261 - hackathon_caa25 - INFO - y_train shape: (306888,)
# 2025-09-21 23:01:38,261 - hackathon_caa25 - INFO - y_dev shape: (76722,)
# 2025-09-21 23:01:38,261 - hackathon_caa25 - INFO - w_train shape: (306888,)
# 2025-09-21 23:01:38,262 - hackathon_caa25 - INFO - w_dev shape: (76722,)
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/raw_code/../hackathon_caa25/apply_transformation/utils_transformation/categorical_converter.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   {c + "_num": data[c].replace(CATEGORICAL_CONVERTER) for c in cols}
# 2025-09-21 23:02:16,694 - hackathon_caa25 - INFO - Data processing completed.
# 2025-09-21 23:02:16,694 - hackathon_caa25 - INFO - x_train shape after processing: (306888, 563)
# 2025-09-21 23:02:16,695 - hackathon_caa25 - INFO - x_dev shape after processing: (76722, 563)
# 2025-09-21 23:02:16,695 - hackathon_caa25 - INFO - dataframe shape after processing: (383610, 563)
# 2025-09-21 23:02:16,695 - hackathon_caa25 - INFO - Retyping features...
# 2025-09-21 23:02:19,545 - hackathon_caa25 - INFO - Columns to be removed: []
# 2025-09-21 23:02:19,545 - hackathon_caa25 - INFO - Categorical columns: ['ACTIVIT2', 'VOCATION', 'ADOSS', 'CARACT1', 'CARACT3', 'INDEM1', 'TYPBAT1', 'INDEM2', 'FRCH1', 'FRCH2', 'DEROG2', 'DEROG3', 'DEROG4', 'DEROG5', 'DEROG8', 'DEROG12', 'DEROG13', 'DEROG14', 'DEROG16', 'KAPITAL34', 'KAPITAL35', 'KAPITAL37', 'KAPITAL40', 'KAPITAL41', 'KAPITAL42', 'KAPITAL43', 'RISK6', 'RISK8', 'RISK9', 'RISK10', 'RISK11', 'RISK12', 'RISK13', 'EQUIPEMENT2', 'EQUIPEMENT5', 'ESPINSEE', 'AN_EXERC', 'ZONE', 'ZONE_REGION', 'NBJTX25_MM_A_NBJTX25_MMAX_A', 'NBJTX0_MM_A_NBJTX0_MMAX_A', 'NBJTXI27_MM_A_NBJTXI27_MMAX_A', 'NBJTXS32_MM_A_NBJTXS32_MMAX_A', 'NBJTXI20_MM_A_NBJTXI20_MMAX_A', 'NBJTX30_MM_A_NBJTX30_MMAX_A', 'NBJTX35_MM_A_NBJTX35_MMAX_A', 'NBJTN10_MM_A_NBJTN10_MMAX_A', 'NBJTNI10_MM_A_NBJTNI10_MMAX_A', 'NBJTN5_MM_A_NBJTN5_MMAX_A', 'NBJTNS25_MM_A_NBJTNS25_MMAX_A', 'NBJTNI15_MM_A_NBJTNI15_MMAX_A', 'NBJTNI20_MM_A_NBJTNI20_MMAX_A', 'NBJTNS20_MM_A_NBJTNS20_MMAX_A', 'NBJTMS24_MM_A_NBJTMS24_MMAX_A', 'TAMPLIAB_VOR_MM_A_TAMPLIAB_VOR_MMAX_A', 'TAMPLIM_VOR_MM_A_TAMPLIM_VOR_MMAX_A', 'TM_VOR_MM_A_TM_VOR_MMAX_A', 'TMM_VOR_MM_A_TMM_VOR_MMAX_A', 'TMMAX_VOR_MM_A_TMMAX_VOR_MMAX_A', 'TMMIN_VOR_MM_A_TMMIN_VOR_MMAX_A', 'TN_VOR_MM_A_TN_VOR_MMAX_A', 'TNAB_VOR_MM_A_TNAB_VOR_MMAX_A', 'TNMAX_VOR_MM_A_TNMAX_VOR_MMAX_A', 'TX_VOR_MM_A_TX_VOR_MMAX_A', 'TXAB_VOR_MM_A_TXAB_VOR_MMAX_A', 'TXMIN_VOR_MM_A_TXMIN_VOR_MMAX_A', 'NBJFF10_MM_A_NBJFF10_MMAX_A', 'NBJFF16_MM_A_NBJFF16_MMAX_A', 'NBJFF28_MM_A_NBJFF28_MMAX_A', 'NBJFXI3S10_MM_A_NBJFXI3S10_MMAX_A', 'NBJFXI3S16_MM_A_NBJFXI3S16_MMAX_A', 'NBJFXI3S28_MM_A_NBJFXI3S28_MMAX_A', 'NBJFXY8_MM_A_NBJFXY8_MMAX_A', 'NBJFXY10_MM_A_NBJFXY10_MMAX_A', 'NBJFXY15_MM_A_NBJFXY15_MMAX_A', 'FFM_VOR_MM_A_FFM_VOR_MMAX_A', 'FXI3SAB_VOR_MM_A_FXI3SAB_VOR_MMAX_A', 'FXIAB_VOR_MM_A_FXIAB_VOR_MMAX_A', 'FXYAB_VOR_MM_A_FXYAB_VOR_MMAX_A', 'FFM_VOR_COM_MM_A_Y_FFM_VOR_COM_MMAX_A_Y', 'FXI3SAB_VOR_COM_MM_A_Y_FXI3SAB_VOR_COM_MMAX_A_Y', 'NBJRR50_MM_A_NBJRR50_MMAX_A', 'NBJRR1_MM_A_NBJRR1_MMAX_A', 'NBJRR5_MM_A_NBJRR5_MMAX_A', 'NBJRR10_MM_A_NBJRR10_MMAX_A', 'NBJRR30_MM_A_NBJRR30_MMAX_A', 'NBJRR100_MM_A_NBJRR100_MMAX_A', 'RR_VOR_MM_A_RR_VOR_MMAX_A', 'RRAB_VOR_MM_A_RRAB_VOR_MMAX_A', 'total_surface_crossed', 'nb_casernes_extinction_rate', 'zone_vent_extinction_rate', 'VENT_x_CASERNES', 'TYPERS'], number of features :94
# 2025-09-21 23:02:19,546 - hackathon_caa25 - INFO - Numerical columns: ['ANCIENNETE', 'CARACT2', 'DUREE_REQANEUF', 'CARACT5', 'TYPBAT2', 'DEROG1', 'DEROG6', 'DEROG7', 'DEROG9', 'DEROG10', 'DEROG11', 'DEROG15', 'CA1', 'CA2', 'CA3', 'KAPITAL1', 'KAPITAL2', 'KAPITAL3', 'KAPITAL4', 'KAPITAL5', 'KAPITAL6', 'KAPITAL7', 'KAPITAL8', 'KAPITAL9', 'KAPITAL10', 'KAPITAL11', 'KAPITAL12', 'KAPITAL13', 'KAPITAL14', 'KAPITAL15', 'KAPITAL16', 'KAPITAL17', 'KAPITAL18', 'KAPITAL19', 'KAPITAL20', 'KAPITAL21', 'KAPITAL22', 'KAPITAL23', 'KAPITAL24', 'KAPITAL25', 'KAPITAL26', 'KAPITAL27', 'KAPITAL28', 'KAPITAL29', 'KAPITAL30', 'KAPITAL31', 'KAPITAL32', 'KAPITAL33', 'KAPITAL36', 'KAPITAL38', 'KAPITAL39', 'SURFACE1', 'SURFACE2', 'SURFACE3', 'SURFACE5', 'SURFACE7', 'SURFACE8', 'SURFACE9', 'SURFACE10', 'SURFACE11', 'SURFACE12', 'SURFACE13', 'SURFACE14', 'SURFACE15', 'SURFACE16', 'SURFACE17', 'SURFACE18', 'SURFACE19', 'SURFACE20', 'SURFACE21', 'NBBAT1', 'NBBAT2', 'NBBAT3', 'NBBAT4', 'NBBAT5', 'NBBAT6', 'NBBAT7', 'NBBAT8', 'NBBAT9', 'NBBAT10', 'NBBAT11', 'NBBAT13', 'NBBAT14', 'TAILLE3', 'TAILLE4', 'NBSINCONJ', 'NBSINSTRT', 'RISK1', 'RISK2', 'RISK3', 'RISK4', 'RISK5', 'RISK7', 'EQUIPEMENT1', 'EQUIPEMENT3', 'EQUIPEMENT4', 'EQUIPEMENT6', 'EQUIPEMENT7', 'ZONE_VENT', 'ANNEE_ASSURANCE', 'FREQ', 'CM', 'CHARGE', 'TARGET', 'CA_TOT', 'CA_MEAN', 'CA1_CA_TOT', 'CA1_CA_MEAN', 'CA2_CA_TOT', 'CA2_CA_MEAN', 'CA3_CA_TOT', 'CA3_CA_MEAN', 'LOG_AVA1_num', 'LOG_A1_A2_num', 'LOG_A2_A3_num', 'LOG_APA3_num', 'LOG_INC_num', 'LOG_SOC_num', 'LOG_TOT', 'LOG_AVA1_num_LOG_TOT', 'LOG_A1_A2_num_LOG_TOT', 'LOG_A2_A3_num_LOG_TOT', 'LOG_APA3_num_LOG_TOT', 'LOG_INC_num_LOG_TOT', 'LOG_SOC_num_LOG_TOT', 'LOG_VETUSTE', 'LOG_REGION', 'LOG_VETUSTE_REGION', 'MEN_PAUV_num', 'MEN_1IND_num', 'MEN_5IND_num', 'MEN_PROP_num', 'MEN_FMP_num', 'MEN_COLL_num', 'MEN_MAIS_num', 'MEN_num', 'MEN_TOT', 'MEN_PAUV_MEN_TOT', 'MEN_PAUV_MEN', 'MEN_1IND_MEN_TOT', 'MEN_1IND_MEN', 'MEN_5IND_MEN_TOT', 'MEN_5IND_MEN', 'MEN_PROP_MEN_TOT', 'MEN_PROP_MEN', 'MEN_FMP_MEN_TOT', 'MEN_FMP_MEN', 'MEN_COLL_MEN_TOT', 'MEN_COLL_MEN', 'MEN_MAIS_MEN_TOT', 'MEN_MAIS_MEN', 'MEN_MEN_TOT', 'MEN_REGION', 'IND_num', 'IND_0_Y1_num', 'IND_Y1_Y2_num', 'IND_Y2_Y3_num', 'IND_Y3_Y4_num', 'IND_Y4_Y5_num', 'IND_Y5_Y6_num', 'IND_Y6_Y7_num', 'IND_Y7_Y8_num', 'IND_Y8_Y9_num', 'IND_Y9_num', 'IND_INC_num', 'IND_SNV_num', 'IND_TOT', 'IND_IND_TOT', 'IND_IND_SNV', 'IND_0_Y1_IND_TOT', 'IND_0_Y1_IND', 'IND_0_Y1_IND_SNV', 'IND_Y1_Y2_IND_TOT', 'IND_Y1_Y2_IND', 'IND_Y1_Y2_IND_SNV', 'IND_Y2_Y3_IND_TOT', 'IND_Y2_Y3_IND', 'IND_Y2_Y3_IND_SNV', 'IND_Y3_Y4_IND_TOT', 'IND_Y3_Y4_IND', 'IND_Y3_Y4_IND_SNV', 'IND_Y4_Y5_IND_TOT', 'IND_Y4_Y5_IND', 'IND_Y4_Y5_IND_SNV', 'IND_Y5_Y6_IND_TOT', 'IND_Y5_Y6_IND', 'IND_Y5_Y6_IND_SNV', 'IND_Y6_Y7_IND_TOT', 'IND_Y6_Y7_IND', 'IND_Y6_Y7_IND_SNV', 'IND_Y7_Y8_IND_TOT', 'IND_Y7_Y8_IND', 'IND_Y7_Y8_IND_SNV', 'IND_Y8_Y9_IND_TOT', 'IND_Y8_Y9_IND', 'IND_Y8_Y9_IND_SNV', 'IND_Y9_IND_TOT', 'IND_Y9_IND', 'IND_Y9_IND_SNV', 'IND_INC_IND_TOT', 'IND_INC_IND', 'IND_INC_IND_SNV', 'IND_SNV_IND_TOT', 'IND_SNV_IND', 'IND_REGION', 'IND_SNV_REGION', 'ALTITUDE_1_num', 'ALTITUDE_2_num', 'ALTITUDE_3_num', 'ALTITUDE_4_num', 'ALTITUDE_5_num', 'ALTITUDE_TOT', 'ALTITUDE_1_ALT_TOT', 'ALTITUDE_2_ALT_TOT', 'ALTITUDE_3_ALT_TOT', 'ALTITUDE_4_ALT_TOT', 'ALTITUDE_5_ALT_TOT', 'ALTITUDE_REGION', 'Accidentelle', 'Involontaire (particulier)', 'Involontaire (travaux)', 'Malveillance', 'Naturelle', 'Unknown', 'KAPITAL_SUM', 'KAPITAL_MAX', 'DEROG13_formatted', 'DEROG8_formatted', 'DEROG3_formatted', 'DEROG16_formatted', 'DEROG14_formatted'], number of features :231
# 2025-09-21 23:02:19,546 - hackathon_caa25 - INFO - Ordinal columns: ['NB_CASERNES', 'BDTOPO_BAT_MAX_HAUTEUR', 'HAUTEUR_MAX', 'HAUTEUR', 'BDTOPO_BAT_MAX_HAUTEUR_MAX', 'MEN_SURF', 'IND_SNV', 'IND_INC', 'IND_Y9', 'IND_0_Y1', 'IND', 'LOG_SOC', 'LOG_INC', 'LOG_APA3', 'LOG_AVA1', 'MEN_MAIS', 'MEN_COLL', 'MEN_FMP', 'MEN_PROP', 'MEN_PAUV', 'MEN', 'COEFASS', 'DISTANCE_111', 'DISTANCE_112', 'DISTANCE_121', 'DISTANCE_122', 'DISTANCE_123', 'DISTANCE_124', 'DISTANCE_131', 'DISTANCE_132', 'DISTANCE_133', 'DISTANCE_141', 'DISTANCE_142', 'DISTANCE_211', 'DISTANCE_212', 'DISTANCE_213', 'DISTANCE_221', 'DISTANCE_222', 'DISTANCE_223', 'DISTANCE_231', 'DISTANCE_242', 'DISTANCE_243', 'DISTANCE_244', 'DISTANCE_311', 'DISTANCE_312', 'DISTANCE_313', 'DISTANCE_321', 'DISTANCE_322', 'DISTANCE_323', 'DISTANCE_324', 'DISTANCE_331', 'DISTANCE_332', 'DISTANCE_333', 'DISTANCE_334', 'DISTANCE_335', 'DISTANCE_411', 'DISTANCE_412', 'DISTANCE_421', 'DISTANCE_422', 'DISTANCE_423', 'DISTANCE_511', 'DISTANCE_512', 'DISTANCE_521', 'DISTANCE_522', 'DISTANCE_523', 'PROPORTION_11', 'PROPORTION_12', 'PROPORTION_13', 'PROPORTION_14', 'PROPORTION_21', 'PROPORTION_22', 'PROPORTION_23', 'PROPORTION_24', 'PROPORTION_31', 'PROPORTION_32', 'PROPORTION_33', 'PROPORTION_41', 'PROPORTION_42', 'PROPORTION_51', 'PROPORTION_52', 'MEN_1IND', 'MEN_5IND', 'LOG_A1_A2', 'LOG_A2_A3', 'IND_Y1_Y2', 'IND_Y2_Y3', 'IND_Y3_Y4', 'IND_Y4_Y5', 'IND_Y5_Y6', 'IND_Y6_Y7', 'IND_Y7_Y8', 'IND_Y8_Y9', 'DISTANCE_1', 'DISTANCE_2', 'ALTITUDE_1', 'ALTITUDE_2', 'ALTITUDE_3', 'ALTITUDE_4', 'ALTITUDE_5', 'NBJTX25_MM_A', 'NBJTX25_MMAX_A', 'NBJTX25_MSOM_A', 'NBJTX0_MM_A', 'NBJTX0_MMAX_A', 'NBJTX0_MSOM_A', 'NBJTXI27_MM_A', 'NBJTXI27_MMAX_A', 'NBJTXI27_MSOM_A', 'NBJTXS32_MM_A', 'NBJTXS32_MMAX_A', 'NBJTXS32_MSOM_A', 'NBJTXI20_MM_A', 'NBJTXI20_MMAX_A', 'NBJTXI20_MSOM_A', 'NBJTX30_MM_A', 'NBJTX30_MMAX_A', 'NBJTX30_MSOM_A', 'NBJTX35_MM_A', 'NBJTX35_MMAX_A', 'NBJTX35_MSOM_A', 'NBJTN10_MM_A', 'NBJTN10_MMAX_A', 'NBJTN10_MSOM_A', 'NBJTNI10_MM_A', 'NBJTNI10_MMAX_A', 'NBJTNI10_MSOM_A', 'NBJTN5_MM_A', 'NBJTN5_MMAX_A', 'NBJTN5_MSOM_A', 'NBJTNS25_MM_A', 'NBJTNS25_MMAX_A', 'NBJTNS25_MSOM_A', 'NBJTNI15_MM_A', 'NBJTNI15_MMAX_A', 'NBJTNI15_MSOM_A', 'NBJTNI20_MM_A', 'NBJTNI20_MMAX_A', 'NBJTNI20_MSOM_A', 'NBJTNS20_MM_A', 'NBJTNS20_MMAX_A', 'NBJTNS20_MSOM_A', 'NBJTMS24_MM_A', 'NBJTMS24_MMAX_A', 'NBJTMS24_MSOM_A', 'TAMPLIAB_VOR_MM_A', 'TAMPLIAB_VOR_MMAX_A', 'TAMPLIM_VOR_MM_A', 'TAMPLIM_VOR_MMAX_A', 'TM_VOR_MM_A', 'TM_VOR_MMAX_A', 'TMM_VOR_MM_A', 'TMM_VOR_MMAX_A', 'TMMAX_VOR_MM_A', 'TMMAX_VOR_MMAX_A', 'TMMIN_VOR_MM_A', 'TMMIN_VOR_MMAX_A', 'TN_VOR_MM_A', 'TN_VOR_MMAX_A', 'TNAB_VOR_MM_A', 'TNAB_VOR_MMAX_A', 'TNMAX_VOR_MM_A', 'TNMAX_VOR_MMAX_A', 'TX_VOR_MM_A', 'TX_VOR_MMAX_A', 'TXAB_VOR_MM_A', 'TXAB_VOR_MMAX_A', 'TXMIN_VOR_MM_A', 'TXMIN_VOR_MMAX_A', 'NBJFF10_MM_A', 'NBJFF10_MMAX_A', 'NBJFF10_MSOM_A', 'NBJFF16_MM_A', 'NBJFF16_MMAX_A', 'NBJFF16_MSOM_A', 'NBJFF28_MM_A', 'NBJFF28_MMAX_A', 'NBJFF28_MSOM_A', 'NBJFXI3S10_MM_A', 'NBJFXI3S10_MMAX_A', 'NBJFXI3S10_MSOM_A', 'NBJFXI3S16_MM_A', 'NBJFXI3S16_MMAX_A', 'NBJFXI3S16_MSOM_A', 'NBJFXI3S28_MM_A', 'NBJFXI3S28_MMAX_A', 'NBJFXI3S28_MSOM_A', 'NBJFXY8_MM_A', 'NBJFXY8_MMAX_A', 'NBJFXY8_MSOM_A', 'NBJFXY10_MM_A', 'NBJFXY10_MMAX_A', 'NBJFXY10_MSOM_A', 'NBJFXY15_MM_A', 'NBJFXY15_MMAX_A', 'NBJFXY15_MSOM_A', 'FFM_VOR_MM_A', 'FFM_VOR_MMAX_A', 'FXI3SAB_VOR_MM_A', 'FXI3SAB_VOR_MMAX_A', 'FXIAB_VOR_MM_A', 'FXIAB_VOR_MMAX_A', 'FXYAB_VOR_MM_A', 'FXYAB_VOR_MMAX_A', 'FFM_VOR_COM_MM_A_Y', 'FFM_VOR_COM_MMAX_A_Y', 'FXI3SAB_VOR_COM_MM_A_Y', 'FXI3SAB_VOR_COM_MMAX_A_Y', 'NBJRR50_MM_A', 'NBJRR50_MMAX_A', 'NBJRR50_MSOM_A', 'NBJRR1_MM_A', 'NBJRR1_MMAX_A', 'NBJRR1_MSOM_A', 'NBJRR5_MM_A', 'NBJRR5_MMAX_A', 'NBJRR5_MSOM_A', 'NBJRR10_MM_A', 'NBJRR10_MMAX_A', 'NBJRR10_MSOM_A', 'NBJRR30_MM_A', 'NBJRR30_MMAX_A', 'NBJRR30_MSOM_A', 'NBJRR100_MM_A', 'NBJRR100_MMAX_A', 'NBJRR100_MSOM_A', 'RR_VOR_MM_A', 'RR_VOR_MMAX_A', 'RRAB_VOR_MM_A', 'RRAB_VOR_MMAX_A', 'TAILLE1', 'TAILLE2', 'CARACT4', 'SURFACE4', 'SURFACE6', 'total_surface_2023', 'to ...
# 2025-09-21 23:02:19,547 - hackathon_caa25 - INFO - Loading existing AutoCarver from /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/hackathon_caa25/data/010_freq_carver.json
# 2025-09-21 23:02:19,566 - hackathon_caa25 - INFO - AutoCarver loaded successfully.
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/.venv/lib/python3.12/site-packages/AutoCarver/discretizers/utils/base_discretizer.py:441: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sample.X.replace(
# /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/.venv/lib/python3.12/site-packages/AutoCarver/discretizers/utils/base_discretizer.py:441: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sample.X.replace(
# 2025-09-21 23:03:17,428 - hackathon_caa25 - INFO - Train & dev transformed using AutoCarver.
# 2025-09-21 23:03:17,428 - hackathon_caa25 - INFO - Loading existing AutoCarver selector from /Users/zachariebuisson/Documents/GitHub/hackathon_caa25/hackathon_caa25/data/010_freq_best_features.json
# 2025-09-21 23:03:17,429 - hackathon_caa25 - INFO - Number of selected quantitative features: 100
#        ACTIVIT2 VOCATION  TYPERS  ANCIENNETE ADOSS CARACT1  CARACT2 CARACT3  \
# ID
# 1          ACT1     VOC6       1           0     N       N      NaN     NaN
# 2          ACT1     VOC6       1           0     N       N      NaN     NaN
# 3          ACT1     VOC6       1           2     N       R      NaN     NaN
# 4          ACT1     VOC6       2           0     N       N      NaN     NaN
# 5          ACT1     VOC6       2           1     N       N      NaN     NaN
# ...         ...      ...     ...         ...   ...     ...      ...     ...
# 383606     ACT5     VOC6       2           5     N       N      NaN     NaN
# 383607     ACT5     VOC6       2          11     N       N      NaN     NaN
# 383608     ACT1     VOC6       1          10     N       N      NaN     NaN
# 383609     ACT1     VOC6       2           0     N       N      NaN     NaN
# 383610     ACT1     VOC8       2           9     N       N      NaN     NaN
#
#        INDEM1  DUREE_REQANEUF  ... Naturelle  Unknown VENT_x_CASERNES  \
# ID                             ...
# 1           N             NaN  ...       0.0      8.0   2.0__02. <= 3
# 2           N             NaN  ...       0.0      8.0   2.0__01. <= 1
# 3           N             NaN  ...       0.0      8.0   2.0__01. <= 1
# 4           N             NaN  ...       0.0      8.0   2.0__01. <= 1
# 5           N             NaN  ...       0.0      8.0   1.0__01. <= 1
# ...       ...             ...  ...       ...      ...             ...
# 383606      N             2.0  ...       0.0      1.0  2.0__03. <= 14
# 383607      N             2.0  ...       0.0      1.0   2.0__02. <= 3
# 383608      N             2.0  ...       0.0      1.0   2.0__01. <= 1
# 383609      N             2.0  ...       0.0      1.0  2.0__03. <= 14
# 383610      N             2.0  ...       0.0      1.0   2.0__01. <= 1
#
#        KAPITAL_SUM  KAPITAL_MAX DEROG13_formatted DEROG8_formatted  \
# ID
# 1         253001.0     125000.0                 0                0
# 2         133502.0     125000.0                 0                0
# 3         128003.0     125000.0                 0                0
# 4         166000.0     125000.0                 0                0
# 5         279000.0     125000.0                 0                0
# ...            ...          ...               ...              ...
# 383606    229500.0      62500.0                 0                0
# 383607    809002.0     225000.0                 0                0
# 383608    326000.0     175000.0                 0                0
# 383609     42001.0       7500.0                 0                0
# 383610     20000.0      20000.0                 0                0
#
#         DEROG3_formatted DEROG16_formatted DEROG14_formatted
# ID
# 1                      0                 0                 0
# 2                      0                 0                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# 5                      0                 0                 0
# ...                  ...               ...               ...
# 383606                 0                 0                 0
# 383607                 0                 0                 0
# 383608                 0                 0                 0
# 383609                 0                 0                 0
# 383610                 0                 0                 0
#
# [383610 rows x 563 columns]

# %%
target
# Out:
#         FREQ   CM  ANNEE_ASSURANCE  CHARGE
# ID
# 1        0.0  0.0         1.000000     0.0
# 2        0.0  0.0         1.000000     0.0
# 3        0.0  0.0         0.402740     0.0
# 4        0.0  0.0         0.246575     0.0
# 5        0.0  0.0         0.838356     0.0
# ...      ...  ...              ...     ...
# 383606   0.0  0.0         1.000000     0.0
# 383607   0.0  0.0         1.000000     0.0
# 383608   0.0  0.0         1.000000     0.0
# 383609   0.0  0.0         1.000000     0.0
# 383610   0.0  0.0         1.000000     0.0
#
# [383610 rows x 4 columns]
