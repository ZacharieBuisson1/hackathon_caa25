# %%
import pandas as pd 

from app.entities import DataInput

train_dataset = pd.read_csv("./app/resources/data/x_train.csv")
features = train_dataset.columns

data_input = DataInput(train_dataset)
# Out:
# /var/folders/qf/pxq_c1s53jn0j_nkpfcjpxfm0000gn/T/ipykernel_27425/244632752.py:5: DtypeWarning: Columns (16,17,29,30,31,126,128,129,132,133,135,138,371) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_dataset = pd.read_csv("./app/resources/data/x_train.csv")
